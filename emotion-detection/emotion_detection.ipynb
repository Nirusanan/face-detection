# %%
# !wget https://www.dropbox.com/s/nilt43hyl1dx82k/dataset.zip?dl=0
# Out:
# --2024-05-08 10:46:59--  https://www.dropbox.com/s/nilt43hyl1dx82k/dataset.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/nilt43hyl1dx82k/dataset.zip [following]
# --2024-05-08 10:46:59--  https://www.dropbox.com/s/raw/nilt43hyl1dx82k/dataset.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc51baf3cdd9668339993efb40ec.dl.dropboxusercontent.com/cd/0/inline/CShMER83Ik8mUhamnZejF9BSWozPFQyrN5NfgL5w0UzWDAM9p7ktR9dgFn6QDYWO3yKmrWmQYKUt5TRnLQ-XVpUH0RRDmgDgdEM0JosNd_hETMoz7G-Pjh0I7jVZdr64f_tt_60oelMFoxjh1rA_1gEO/file# [following]
# --2024-05-08 10:47:00--  https://uc51baf3cdd9668339993efb40ec.dl.dropboxusercontent.com/cd/0/inline/CShMER83Ik8mUhamnZejF9BSWozPFQyrN5NfgL5w0UzWDAM9p7ktR9dgFn6QDYWO3yKmrWmQYKUt5TRnLQ-XVpUH0RRDmgDgdEM0JosNd_hETMoz7G-Pjh0I7jVZdr64f_tt_60oelMFoxjh1rA_1gEO/file
# Resolving uc51baf3cdd9668339993efb40ec.dl.dropboxusercontent.com (uc51baf3cdd9668339993efb40ec.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to uc51baf3cdd9668339993efb40ec.dl.dropboxusercontent.com (uc51baf3cdd9668339993efb40ec.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CSjxhmbxBy15bHgvsKEVKD0ou2VdgxhQXvI2K89lcOaWwmEICbDqBUywJ1b-YlJ8ptSWKzx-ZfRgBnoQsOX4nDjuQayhTyU547f6JSxFXJ_EQI_whAGB5tdkv52eG1sQE_UK4byRCNk9vX0b3KZ38P5IsVrDoXDOrydF6J4t0yBo9LZSKw1b_yKLUiCTW0D-nrPIo9RP9n29YvwNvdiTKP_5KXlaFK17HxrRHG1lQMwFPnK2D_KnvzVBT8qQQ77xOqzOeeuXP16ger-iquYzuvyZBT_QLrO6IZPpbef_Nqka9obAFnAAGe6x2W0DXIF1gdaPycjUqmwfRqDyiOxRZ77EgfDAyN8uMIA3q0-Q7dWme9r-chZRFovLv8RHfa4pDQo/file [following]
# --2024-05-08 10:47:01--  https://uc51baf3cdd9668339993efb40ec.dl.dropboxusercontent.com/cd/0/inline2/CSjxhmbxBy15bHgvsKEVKD0ou2VdgxhQXvI2K89lcOaWwmEICbDqBUywJ1b-YlJ8ptSWKzx-ZfRgBnoQsOX4nDjuQayhTyU547f6JSxFXJ_EQI_whAGB5tdkv52eG1sQE_UK4byRCNk9vX0b3KZ38P5IsVrDoXDOrydF6J4t0yBo9LZSKw1b_yKLUiCTW0D-nrPIo9RP9n29YvwNvdiTKP_5KXlaFK17HxrRHG1lQMwFPnK2D_KnvzVBT8qQQ77xOqzOeeuXP16ger-iquYzuvyZBT_QLrO6IZPpbef_Nqka9obAFnAAGe6x2W0DXIF1gdaPycjUqmwfRqDyiOxRZ77EgfDAyN8uMIA3q0-Q7dWme9r-chZRFovLv8RHfa4pDQo/file
# Reusing existing connection to uc51baf3cdd9668339993efb40ec.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 63252113 (60M) [application/zip]
# Saving to: ‘dataset.zip?dl=0’
#
# dataset.zip?dl=0    100%[===================>]  60.32M  54.9MB/s    in 1.1s
#
# 2024-05-08 10:47:02 (54.9 MB/s) - ‘dataset.zip?dl=0’ saved [63252113/63252113]

# %%
# !unzip dataset.zip?dl=0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.layers import Flatten, Dense
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator , img_to_array, load_img
from keras.applications.mobilenet import MobileNet, preprocess_input
from keras.losses import categorical_crossentropy

# %% [markdown]
# #  Building our Model To train the data

# %%
# Working with pre trained model

base_model = MobileNet( input_shape=(224,224,3), include_top= False )

for layer in base_model.layers:
  layer.trainable = False


x = Flatten()(base_model.output)
x = Dense(units=7 , activation='softmax' )(x)

# creating our model.
model = Model(base_model.input, x)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 [==============================] - 0s 0us/step

# %%
model.compile(optimizer='adam', loss= categorical_crossentropy , metrics=['accuracy']  )

# %% [markdown]
# # Preparing our data using data generator

# %%
train_datagen = ImageDataGenerator(
     zoom_range = 0.2,
     shear_range = 0.2,
     horizontal_flip=True,
     rescale = 1./255
)

train_data = train_datagen.flow_from_directory(directory= "/content/train",
                                               target_size=(224,224),
                                               batch_size=32,
                                  )


train_data.class_indices
# Out:
# Found 28709 images belonging to 7 classes.
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
val_datagen = ImageDataGenerator(rescale = 1./255 )

val_data = val_datagen.flow_from_directory(directory= "/content/test",
                                           target_size=(224,224),
                                           batch_size=32,
                                  )
# Out:
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # visualizaing the data that is fed to train data gen

# %%
# to visualize the images in the traing data denerator

t_img , label = train_data.next()

#-----------------------------------------------------------------------------
# function when called will prot the images
def plotImages(img_arr, label):
  """
  input  :- images array
  output :- plots the images
  """
  count = 0
  for im, l in zip(img_arr,label) :
    plt.imshow(im)
    plt.title(im.shape)
    plt.axis = False
    plt.show()

    count += 1
    if count == 10:
      break

#-----------------------------------------------------------------------------
# function call to plot the images
plotImages(t_img, label)

# %% [markdown]
# # having early stopping and model check point

# %%
## having early stopping and model check point

from keras.callbacks import ModelCheckpoint, EarlyStopping

# early stopping
es = EarlyStopping(monitor='val_accuracy', min_delta= 0.01 , patience= 5, verbose= 1, mode='auto')

# model check point
mc = ModelCheckpoint(filepath="best_model.h5", monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode = 'auto')

# puting call back in a list
call_back = [es, mc]

# %%
hist = model.fit_generator(train_data,
                           steps_per_epoch= 10,
                           epochs= 30,
                           validation_data= val_data,
                           validation_steps= 8,
                           callbacks=[es,mc])
# Out:
# <ipython-input-10-f681b3c69731>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(train_data,
# Epoch 1/30
# 10/10 [==============================] - ETA: 0s - loss: 16.8012 - accuracy: 0.1937
# Epoch 1: val_accuracy improved from -inf to 0.17578, saving model to best_model.h5
# 10/10 [==============================] - 34s 3s/step - loss: 16.8012 - accuracy: 0.1937 - val_loss: 12.5367 - val_accuracy: 0.1758
# Epoch 2/30
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 10/10 [==============================] - ETA: 0s - loss: 10.3703 - accuracy: 0.3406
# Epoch 2: val_accuracy improved from 0.17578 to 0.36328, saving model to best_model.h5
# 10/10 [==============================] - 39s 4s/step - loss: 10.3703 - accuracy: 0.3406 - val_loss: 6.6176 - val_accuracy: 0.3633
# Epoch 3/30
# 10/10 [==============================] - ETA: 0s - loss: 6.5108 - accuracy: 0.3750
# Epoch 3: val_accuracy improved from 0.36328 to 0.44141, saving model to best_model.h5
# 10/10 [==============================] - 40s 4s/step - loss: 6.5108 - accuracy: 0.3750 - val_loss: 5.3239 - val_accuracy: 0.4414
# Epoch 4/30
# 10/10 [==============================] - ETA: 0s - loss: 5.6027 - accuracy: 0.3531
# Epoch 4: val_accuracy did not improve from 0.44141
# 10/10 [==============================] - 40s 4s/step - loss: 5.6027 - accuracy: 0.3531 - val_loss: 5.0044 - val_accuracy: 0.3789
# Epoch 5/30
# 10/10 [==============================] - ETA: 0s - loss: 5.1924 - accuracy: 0.3906
# Epoch 5: val_accuracy did not improve from 0.44141
# 10/10 [==============================] - 29s 3s/step - loss: 5.1924 - accuracy: 0.3906 - val_loss: 5.7149 - val_accuracy: 0.3711
# Epoch 6/30
# 10/10 [==============================] - ETA: 0s - loss: 6.0737 - accuracy: 0.3938
# Epoch 6: val_accuracy did not improve from 0.44141
# 10/10 [==============================] - 30s 3s/step - loss: 6.0737 - accuracy: 0.3938 - val_loss: 5.5956 - val_accuracy: 0.3984
# Epoch 7/30
# 10/10 [==============================] - ETA: 0s - loss: 5.1254 - accuracy: 0.4313
# Epoch 7: val_accuracy did not improve from 0.44141
# 10/10 [==============================] - 38s 4s/step - loss: 5.1254 - accuracy: 0.4313 - val_loss: 6.1279 - val_accuracy: 0.3633
# Epoch 8/30
# 10/10 [==============================] - ETA: 0s - loss: 5.0609 - accuracy: 0.4250
# Epoch 8: val_accuracy improved from 0.44141 to 0.48438, saving model to best_model.h5
# 10/10 [==============================] - 30s 3s/step - loss: 5.0609 - accuracy: 0.4250 - val_loss: 5.4005 - val_accuracy: 0.4844
# Epoch 9/30
# 10/10 [==============================] - ETA: 0s - loss: 7.0681 - accuracy: 0.3750
# Epoch 9: val_accuracy did not improve from 0.48438
# 10/10 [==============================] - 29s 3s/step - loss: 7.0681 - accuracy: 0.3750 - val_loss: 8.7018 - val_accuracy: 0.4258
# Epoch 10/30
# 10/10 [==============================] - ETA: 0s - loss: 8.3472 - accuracy: 0.3906
# Epoch 10: val_accuracy did not improve from 0.48438
# 10/10 [==============================] - 39s 4s/step - loss: 8.3472 - accuracy: 0.3906 - val_loss: 8.3333 - val_accuracy: 0.3672
# Epoch 11/30
# 10/10 [==============================] - ETA: 0s - loss: 6.8440 - accuracy: 0.3969
# Epoch 11: val_accuracy did not improve from 0.48438
# 10/10 [==============================] - 40s 4s/step - loss: 6.8440 - accuracy: 0.3969 - val_loss: 7.5958 - val_accuracy: 0.4180
# Epoch 12/30
# 10/10 [==============================] - ETA: 0s - loss: 6.1493 - accuracy: 0.4594
# Epoch 12: val_accuracy did not improve from 0.48438
# 10/10 [==============================] - 30s 3s/step - loss: 6.1493 - accuracy: 0.4594 - val_loss: 5.7256 - val_accuracy: 0.4609
# Epoch 13/30
# 10/10 [==============================] - ETA: 0s - loss: 6.0295 - accuracy: 0.4313
# Epoch 13: val_accuracy did not improve from 0.48438
# 10/10 [==============================] - 29s 3s/step - loss: 6.0295 - accuracy: 0.4313 - val_loss: 7.6475 - val_accuracy: 0.3867
# Epoch 13: early stopping

# %%
# Loading the best fit model
from keras.models import load_model
model = load_model("/content/best_model.h5")

# %%
h =  hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
# just to map o/p values
op = dict(zip( train_data.class_indices.values(), train_data.class_indices.keys()))

# %%
# path for the image to see if it predics correct class

path = "/content/test/angry/PrivateTest_1054527.jpg"
img = load_img(path, target_size=(224,224) )

i = img_to_array(img)/255
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))

print(f" the image is of {op[pred]}")

# to display the image
plt.imshow(input_arr[0])
plt.title("input image")
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step
#  the image is of sad
